# %%
# !pip install constellate-client

# %%
import constellate
import csv

# %%
constellate
# Out:
# <module 'constellate' (namespace)>

# %%
with open('./sample_dataset.csv', encoding='utf8') as csvfile:
  reader = csv.reader(csvfile)
  for row in reader:
    dataset_metadata = constellate.client.get_metadata(row[6])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19372\1735148939.py in <module>
#       2   reader = csv.reader(csvfile)
#       3   for row in reader:
# ----> 4     dataset_metadata = constellate.client.get_metadata(row[6])
#
# ~\anaconda3\lib\site-packages\constellate\client.py in get_metadata(dataset_id, fname, force)
#     128     documents in the dataset.
#     129     """
# --> 130     return _download_file(dataset_id, "sampled-metadata", file_name=fname, force=force)
#     131
#     132
#
# ~\anaconda3\lib\site-packages\constellate\client.py in _download_file(dataset_id, download_type, file_name, force)
#      91 def _download_file(dataset_id, download_type, file_name=None, force=False):
#      92     description = get_description(dataset_id)
# ---> 93     _ = display_description(description)
# ...
